# %% [markdown]
# <a href="https://colab.research.google.com/github/Phalguni-dhabale/MV-LAB/blob/main/MV_PRACTICAL_6_D3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface opencv-python-headless matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.7/170.7 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 kB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 990.7 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 38.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 51.8 MB/s eta 0:00:00
# ...

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
# Out:
# 26-07-28 15:10:17 - Directory /root/.deepface has been created
# 26-07-28 15:10:17 - Directory /root/.deepface/weights has been created

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4d0aa85e-2372-4d92-9d31-828915973323" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d0aa85e-2372-4d92-9d31-828915973323">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image = cv2.imread("customer.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.title("Customer Image")
plt.axis("off")
plt.show()

# %%
result = DeepFace.analyze(
    img_path="customer.jpg",
    actions=['emotion'],
    enforce_detection=False
)

print(result)
# Out:
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 26-07-28 15:14:27 - 🔗 facial_expression_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5 to /root/.deepface/weights/facial_expression_model_weights.h5...
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 79.5MB/s]
# [{'emotion': {'angry': np.float32(1.4647425e-06), 'disgust': np.float32(5.2036756e-12), 'fear': np.float32(2.991382e-06), 'happy': np.float32(95.31918), 'sad': np.float32(0.0012237128), 'surprise': np.float32(0.000119414), 'neutral': np.float32(4.6794724)}, 'dominant_emotion': 'happy', 'region': {'x': 90, 'y': 14, 'w': 52, 'h': 52, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.9}]

# %%
emotion = result[0]['dominant_emotion']
print("Predicted Emotion:", emotion)
# Out:
# Predicted Emotion: happy

# %%
image = cv2.imread("customer.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.title("Detected Emotion: " + emotion)
plt.axis("off")
plt.show()
